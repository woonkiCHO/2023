# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('C:/Users/Owner/Desktop/git/Advertising/소비자 지출 변화율/Percent_Change_in_Consumer_Spending.csv')

# %%
df.head()
# Out:
#    State FIPS code        Date  All merchant category codes spending
# 0              900  01/13/2020                                -1.760  \
# 1             2500  01/13/2020                                -0.220
# 2             3400  01/13/2020                                -0.560
# 3             3600  01/13/2020                                -0.373
# 4             4400  01/13/2020                                -1.850
#
#    Accommodation and food service (ACF) spending
# 0                                          -5.43  \
# 1                                          -2.47
# 2                                          -3.86
# 3                                          -3.64
# 4                                         -15.00
#
#    Arts, entertainment, and recreation (AER)  spending
# 0                                              -13.8    \
# 1                                              -14.0
# 2                                              -11.6
# 3                                              -13.9
# 4                                              -19.1
#
#    General merchandise stores (GEN) and apparel and accessories (AAP) spending
# 0                                             -5.220                            \
# 1                                             -2.310
# 2                                              0.655
# 3                                             -1.460
# 4                                             -5.960
#
#    Grocery and food store (GRF)  spending
# 0                                  -2.760  \
# 1                                   0.309
# 2                                  -0.623
# 3                                  -0.884
# 4                                  -0.105
#
#    Health care and social assistance (HCS) spending
# 0                                               0.89  \
# 1                                               3.51
# 2                                               4.77
# 3                                               7.91
# 4                                               1.23
#
#    Transportation and warehousing (TWS)  spending
# 0                                           0.466  \
# 1                                          -1.920
# 2                                           1.230
# 3                                          -0.107
# 4                                         -31.200
#
#    Retail spending, including grocery  (AAP, CEC, GEN, GRF, HIC, ETC, SGH)
# 0                                             -3.240                         \
# 1                                              0.300
# 2                                              0.227
# 3                                             -0.548
# 4                                             -4.510
#
#    Retail spending, excluding grocery ((AAP, CEC, GEN, HIC, ETC, SGH)
# 0                                             -3.650
# 1                                              0.208
# 2                                              1.090
# 3                                             -0.256
# 4                                             -9.520

# %%
df.tail()
# Out:
#       State FIPS code        Date  All merchant category codes spending
# 4725              900  10/15/2023                                  30.2  \
# 4726             2500  10/15/2023                                  32.3
# 4727             3400  10/15/2023                                  44.9
# 4728             3600  10/15/2023                                  30.7
# 4729             4400  10/15/2023                                  33.3
#
#       Accommodation and food service (ACF) spending
# 4725                                           21.4  \
# 4726                                           14.7
# 4727                                           30.8
# 4728                                           15.3
# 4729                                            9.9
#
#       Arts, entertainment, and recreation (AER)  spending
# 4725                                               19.2    \
# 4726                                               46.6
# 4727                                               54.5
# 4728                                               38.1
# 4729                                               14.1
#
#       General merchandise stores (GEN) and apparel and accessories (AAP) spending
# 4725                                               21.9                            \
# 4726                                               27.4
# 4727                                               52.3
# 4728                                               31.1
# 4729                                               14.3
#
#       Grocery and food store (GRF)  spending
# 4725                                    29.5  \
# 4726                                    28.7
# 4727                                    14.0
# 4728                                    21.1
# 4729                                    25.2
#
#       Health care and social assistance (HCS) spending
# 4725                                               30.1  \
# 4726                                               47.3
# 4727                                               66.4
# 4728                                               35.0
# 4729                                               35.7
#
#       Transportation and warehousing (TWS)  spending
# 4725                                           -1.80  \
# 4726                                            6.49
# 4727                                           57.50
# 4728                                           18.20
# 4729                                           97.00
#
#       Retail spending, including grocery  (AAP, CEC, GEN, GRF, HIC, ETC, SGH)
# 4725                                               28.9                         \
# 4726                                               29.5
# 4727                                               34.0
# 4728                                               25.6
# 4729                                               25.7
#
#       Retail spending, excluding grocery ((AAP, CEC, GEN, HIC, ETC, SGH)
# 4725                                               28.5
# 4726                                               30.3
# 4727                                               52.4
# 4728                                               29.4
# 4729                                               26.4

# %%
df.shape
# Out:
# (4730, 11)

# %%
df.describe()
# Out:
#        State FIPS code  All merchant category codes spending
# count       4730.00000                           4730.000000  \
# mean        2960.00000                              8.516497
# std         1194.44616                             14.932898
# min          900.00000                            -44.000000
# 25%         2500.00000                             -1.270000
# 50%         3400.00000                             11.800000
# 75%         3600.00000                             19.500000
# max         4400.00000                             45.700000
#
#        Accommodation and food service (ACF) spending
# count                                    4730.000000  \
# mean                                       -7.359320
# std                                        24.818822
# min                                       -75.700000
# 25%                                       -24.900000
# 50%                                        -2.120000
# 75%                                        12.800000
# max                                        47.700000
#
#        Arts, entertainment, and recreation (AER)  spending
# count                                        4730.000000    \
# mean                                          -12.807572
# std                                            33.552783
# min                                           -83.600000
# 25%                                           -40.500000
# 50%                                           -10.500000
# 75%                                            12.700000
# max                                           107.000000
#
#        General merchandise stores (GEN) and apparel and accessories (AAP) spending
# count                                        4730.000000                            \
# mean                                           14.082449
# std                                            18.705340
# min                                           -49.100000
# 25%                                             3.247500
# 50%                                            16.800000
# 75%                                            27.400000
# max                                            67.300000
#
#        Grocery and food store (GRF)  spending
# count                              4730.00000  \
# mean                                 17.46439
# std                                  10.01082
# min                                 -12.60000
# 25%                                  12.32500
# 50%                                  17.30000
# 75%                                  22.10000
# max                                  81.00000
#
#        Health care and social assistance (HCS) spending
# count                                        4730.000000  \
# mean                                            4.509860
# std                                            26.715283
# min                                           -86.100000
# 25%                                            -6.937500
# 50%                                             8.090000
# 75%                                            20.000000
# max                                           152.000000
#
#        Transportation and warehousing (TWS)  spending
# count                                     4730.000000  \
# mean                                       -21.764435
# std                                         41.078123
# min                                       -100.000000
# 25%                                        -56.775000
# 50%                                        -23.300000
# 75%                                         -0.001975
# max                                        239.000000
#
#        Retail spending, including grocery  (AAP, CEC, GEN, GRF, HIC, ETC, SGH)
# count                                        4730.000000                         \
# mean                                           19.394416
# std                                            11.378631
# min                                           -24.000000
# 25%                                            13.300000
# 50%                                            20.700000
# 75%                                            27.000000
# max                                            91.000000
#
#        Retail spending, excluding grocery ((AAP, CEC, GEN, HIC, ETC, SGH)
# count                                        4730.000000
# mean                                           21.518906
# std                                            17.911198
# min                                           -50.500000
# 25%                                            12.600000
# 50%                                            23.400000
# 75%                                            33.000000
# max                                           167.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4730 entries, 0 to 4729
# Data columns (total 11 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   State FIPS code                                                              4730 non-null   int64
#  1   Date                                                                         4730 non-null   object
#  2   All merchant category codes spending                                         4730 non-null   float64
#  3   Accommodation and food service (ACF) spending                                4730 non-null   float64
#  4   Arts, entertainment, and recreation (AER)  spending                          4730 non-null   float64
#  5   General merchandise stores (GEN) and apparel and accessories (AAP) spending  4730 non-null   float64
#  6   Grocery and food store (GRF)  spending                                       4730 non-null   float64
#  7   Health care and social assistance (HCS) spending                             4730 non-null   float64
#  8   Transportation and warehousing (TWS)  spending                               4730 non-null   float64
#  9   Retail spending, including grocery  (AAP, CEC, GEN, GRF, HIC, ETC, SGH)      4730 non-null   float64
#  10  Retail spending, excluding grocery ((AAP, CEC, GEN, HIC, ETC, SGH)           4730 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 406.6+ KB

# %%
df.isnull().sum()
# Out:
# State FIPS code                                                                0
# Date                                                                           0
# All merchant category codes spending                                           0
# Accommodation and food service (ACF) spending                                  0
# Arts, entertainment, and recreation (AER)  spending                            0
# General merchandise stores (GEN) and apparel and accessories (AAP) spending    0
# Grocery and food store (GRF)  spending                                         0
# Health care and social assistance (HCS) spending                               0
# Transportation and warehousing (TWS)  spending                                 0
# Retail spending, including grocery  (AAP, CEC, GEN, GRF, HIC, ETC, SGH)        0
# Retail spending, excluding grocery ((AAP, CEC, GEN, HIC, ETC, SGH)             0
# dtype: int64

# %%
df["State FIPS code"].value_counts()
# Out:
# State FIPS code
# 900     946
# 2500    946
# 3400    946
# 3600    946
# 4400    946
# Name: count, dtype: int64

# %%
#날짜 열에는 "01/13/2020"과 "02-01-2020"의 두 가지 형식이 포함되어 있다.

df['Date'] = df['Date'].str.replace('-', '/')
df['Date'] = pd.to_datetime(df['Date'], format="%m/%d/%Y", errors='coerce')

# %%
grouped = df.groupby("State FIPS code")

TARGET = 'All merchant category codes spending'

plt.figure(figsize=(12, 10))
plt.subplot(211)
for state_fips, group in grouped:
    plt.plot(group.set_index('Date')[TARGET], label=f'State {state_fips}')
    
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.subplot(212)
for state_fips, group in grouped:
    monthly_resampled = group.set_index('Date')[TARGET].resample('M').mean()
    plt.plot(monthly_resampled.index, monthly_resampled, label=f'State {state_fips}')
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.show()

# %%
#주 3400의 성장은 2022년 7월 이후 증가하고 있다.

# %%
TARGET = 'Accommodation and food service (ACF) spending'

plt.figure(figsize=(12, 10))
plt.subplot(211)
for state_fips, group in grouped:
    plt.plot(group.set_index('Date')[TARGET], label=f'State {state_fips}')
    
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.subplot(212)
for state_fips, group in grouped:
    monthly_resampled = group.set_index('Date')[TARGET].resample('M').mean()
    plt.plot(monthly_resampled.index, monthly_resampled, label=f'State {state_fips}')
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.show()

# %%
#2020년 감소(아마도 COVID 2019의 영향으로)에 다른 주보다 주 4400이 더 큰 영향을 받는가?

# %%
TARGET = 'Arts, entertainment, and recreation (AER)  spending'

plt.figure(figsize=(12, 10))
plt.subplot(211)
for state_fips, group in grouped:
    plt.plot(group.set_index('Date')[TARGET], label=f'State {state_fips}')
    
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.subplot(212)
for state_fips, group in grouped:
    monthly_resampled = group.set_index('Date')[TARGET].resample('M').mean()
    plt.plot(monthly_resampled.index, monthly_resampled, label=f'State {state_fips}')
plt.title(f'{TARGET} by State FIPS code')
plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.show()

# %%
TARGET = 'General merchandise stores (GEN) and apparel and accessories (AAP) spending'

plt.figure(figsize=(12, 10))
plt.subplot(211)
for state_fips, group in grouped:
    plt.plot(group.set_index('Date')[TARGET], label=f'State {state_fips}')
    
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.subplot(212)
for state_fips, group in grouped:
    monthly_resampled = group.set_index('Date')[TARGET].resample('M').mean()
    plt.plot(monthly_resampled.index, monthly_resampled, label=f'State {state_fips}')
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.show()

# %%
TARGET = 'Health care and social assistance (HCS) spending '

plt.figure(figsize=(12, 10))
plt.subplot(211)
for state_fips, group in grouped:
    plt.plot(group.set_index('Date')[TARGET], label=f'State {state_fips}')
    
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.subplot(212)
for state_fips, group in grouped:
    monthly_resampled = group.set_index('Date')[TARGET].resample('M').mean()
    plt.plot(monthly_resampled.index, monthly_resampled, label=f'State {state_fips}')
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.show()

# %%
#State 2500

# %%
#State 4400는 매우 불안정한 상태

# %%
TARGET = 'Transportation and warehousing (TWS)  spending'

plt.figure(figsize=(12, 10))
plt.subplot(211)
for state_fips, group in grouped:
    plt.plot(group.set_index('Date')[TARGET], label=f'State {state_fips}')
    
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.subplot(212)
for state_fips, group in grouped:
    monthly_resampled = group.set_index('Date')[TARGET].resample('M').mean()
    plt.plot(monthly_resampled.index, monthly_resampled, label=f'State {state_fips}')
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.show()

# %%
TARGET = 'Retail spending, including grocery  (AAP, CEC, GEN, GRF, HIC, ETC, SGH) '

plt.figure(figsize=(12, 10))
plt.subplot(211)
for state_fips, group in grouped:
    plt.plot(group.set_index('Date')[TARGET], label=f'State {state_fips}')
    
plt.title(f'{TARGET} by State FIPS code')
plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.subplot(212)
for state_fips, group in grouped:
    monthly_resampled = group.set_index('Date')[TARGET].resample('M').mean()
    plt.plot(monthly_resampled.index, monthly_resampled, label=f'State {state_fips}')
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.show()

# %%
TARGET = 'Retail spending, excluding grocery ((AAP, CEC, GEN, HIC, ETC, SGH) '

plt.figure(figsize=(12, 10))
plt.subplot(211)
for state_fips, group in grouped:
    plt.plot(group.set_index('Date')[TARGET], label=f'State {state_fips}')
    
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.subplot(212)
for state_fips, group in grouped:
    monthly_resampled = group.set_index('Date')[TARGET].resample('M').mean()
    plt.plot(monthly_resampled.index, monthly_resampled, label=f'State {state_fips}')
plt.title(f'{TARGET} by State FIPS code')

plt.xlabel('Date')
plt.ylabel(TARGET)

plt.legend()
plt.grid(True)

plt.show()
