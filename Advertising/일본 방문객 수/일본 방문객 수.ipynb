# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Owner/Desktop/git/Advertising/일본 방문객 수/archive/Number of foreign visitors to Japan by month_ .csv')

# %%
df
# Out:
#       Country/Area Month   Year  Visitor
# 0      Afghanistan   Jan.  2017      233
# 1      Afghanistan   Feb.  2017      196
# 2      Afghanistan   Mar.  2017      192
# 3      Afghanistan   Apr.  2017      259
# 4      Afghanistan    May  2017      228
# ...            ...    ...   ...      ...
# 17047     Zimbabwe   Aug.  2023        0
# 17048     Zimbabwe   Sep.  2023        0
# 17049     Zimbabwe   Oct.  2023        0
# 17050     Zimbabwe   Nov.  2023        0
# 17051     Zimbabwe   Dec.  2023        0
#
# [17052 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17052 entries, 0 to 17051
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country/Area  17052 non-null  object
#  1   Month         17052 non-null  object
#  2   Year          17052 non-null  int64
#  3   Visitor       17052 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 533.0+ KB

# %%
df.tail()
# Out:
#       Country/Area Month   Year  Visitor
# 17047     Zimbabwe   Aug.  2023        0
# 17048     Zimbabwe   Sep.  2023        0
# 17049     Zimbabwe   Oct.  2023        0
# 17050     Zimbabwe   Nov.  2023        0
# 17051     Zimbabwe   Dec.  2023        0

# %%
df.shape
# Out:
# (17052, 4)

# %%
df2 = pd.read_csv('C:/Users/Owner/Desktop/git/Advertising/일본 방문객 수/archive/Number of foreign visitors to Japan by year_ .csv')

# %%
df2
# Out:
#     Year  Visitor Arrivals
# 0   1964            352832
# 1   1965            366649
# 2   1966            432937
# 3   1967            476771
# 4   1968            519004
# 5   1969            608744
# 6   1970            854419
# 7   1971            660715
# 8   1972            723744
# 9   1973            784691
# 10  1974            764246
# 11  1975            811672
# 12  1976            914772
# 13  1977           1028140
# 14  1978           1038875
# 15  1979           1112606
# 16  1980           1316632
# 17  1981           1583043
# 18  1982           1793164
# 19  1983           1968461
# 20  1984           2110346
# 21  1985           2327047
# 22  1986           2061526
# 23  1987           2154864
# 24  1988           2355412
# 25  1989           2835064
# 26  1990           3235860
# 27  1991           3532651
# 28  1992           3581540
# 29  1993           3410447
# 30  1994           3468055
# 31  1995           3345274
# 32  1996           3837113
# ...

# %%
df2.tail()
# Out:
#     Year  Visitor Arrivals
# 55  2019          31882049
# 56  2020           4115828
# 57  2021            245862
# 58  2022           3832110
# 59  2023          10712396

# %%
df2.shape
# Out:
# (60, 2)

# %%
df2
# Out:
#     Year  Visitor Arrivals
# 0   1964            352832
# 1   1965            366649
# 2   1966            432937
# 3   1967            476771
# 4   1968            519004
# 5   1969            608744
# 6   1970            854419
# 7   1971            660715
# 8   1972            723744
# 9   1973            784691
# 10  1974            764246
# 11  1975            811672
# 12  1976            914772
# 13  1977           1028140
# 14  1978           1038875
# 15  1979           1112606
# 16  1980           1316632
# 17  1981           1583043
# 18  1982           1793164
# 19  1983           1968461
# 20  1984           2110346
# 21  1985           2327047
# 22  1986           2061526
# 23  1987           2154864
# 24  1988           2355412
# 25  1989           2835064
# 26  1990           3235860
# 27  1991           3532651
# 28  1992           3581540
# 29  1993           3410447
# 30  1994           3468055
# 31  1995           3345274
# 32  1996           3837113
# ...

# %%
df.describe()
# Out:
#                Year       Visitor
# count  17052.000000  1.705200e+04
# mean    2020.000000  6.490217e+03
# std        2.000059  5.015021e+04
# min     2017.000000  0.000000e+00
# 25%     2018.000000  2.000000e+00
# 50%     2020.000000  2.100000e+01
# 75%     2022.000000  1.900000e+02
# max     2023.000000  1.050420e+06

# %%
df.describe().round()
# Out:
#           Year    Visitor
# count  17052.0    17052.0
# mean    2020.0     6490.0
# std        2.0    50150.0
# min     2017.0        0.0
# 25%     2018.0        2.0
# 50%     2020.0       21.0
# 75%     2022.0      190.0
# max     2023.0  1050420.0

# %%
df.isnull().sum()
# Out:
# Country/Area    0
# Month           0
# Year            0
# Visitor         0
# dtype: int64

# %%
df.dtypes
# Out:
# Country/Area    object
# Month           object
# Year             int64
# Visitor          int64
# dtype: object

# %%
df['Country/Area'].value_counts()
# Out:
# Country/Area
# Afghanistan      84
# Poland           84
# Norway           84
# Oman             84
# Pakistan         84
#                  ..
# Guinea-Bissau    84
# Guyana           84
# Haiti            84
# Honduras         84
# Zimbabwe         84
# Name: count, Length: 203, dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
sns.barplot(x='Year', y='Visitor', data=df, orient='v')
# Out:
# <Axes: xlabel='Year', ylabel='Visitor'>

# %%
#2019년에 일본을 방문한 방문객이 그 해에 13,000명 이상으로 가장 많음을 관찰할 수 있다. 코로나가 세계를 강타한 후, 가장 적은 방문객 수는 2021년이었다

# %%
import matplotlib.pyplot as plt

# %%
top_max = df['Visitor'].max()
top_max
# Out:
# 1050420

# %%
max_visitors = df.loc[df['Visitor'] ==  top_max]
max_visitors
# Out:
#      Country/Area Month   Year  Visitor
# 2886        China   Jul.  2019  1050420

# %%
#2019년과 7월에 가장 많은 방문객이 중국에서 왔고 약 10,50,420명이 방문한 것을 알 수 있다

# %%
least_min = df['Visitor'].min()
least_min
# Out:
# 0

# %%
min_visitors = df.loc[df['Visitor'] ==  least_min]
min_visitors
# Out:
#       Country/Area Month   Year  Visitor
# 40     Afghanistan    May  2020        0
# 78     Afghanistan   Jul.  2023        0
# 79     Afghanistan   Aug.  2023        0
# 80     Afghanistan   Sep.  2023        0
# 81     Afghanistan   Oct.  2023        0
# ...            ...    ...   ...      ...
# 17047     Zimbabwe   Aug.  2023        0
# 17048     Zimbabwe   Sep.  2023        0
# 17049     Zimbabwe   Oct.  2023        0
# 17050     Zimbabwe   Nov.  2023        0
# 17051     Zimbabwe   Dec.  2023        0
#
# [3368 rows x 4 columns]

# %%
min_visitors.plot()
# Out:
# <Axes: >

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df_y = df2.set_index('Year')
df_y

plt.figure(figsize=(15,5)) 
plt.xticks(rotation=90) 

sns.lineplot(data=df_y)
# Out:
# <Axes: xlabel='Year'>
